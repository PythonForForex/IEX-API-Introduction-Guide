# %%
import os
import requests

# %%
base_url = 'https://cloud.iexapis.com/v1'
sandbox_url = 'https://sandbox.iexapis.com/stable'

token = os.environ.get('IEX_TOKEN')
params = {'token': token}

# %% [markdown]
# # Check status endpoint to confirm connection

# %%
resp = requests.get(base_url + '/status')

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'status': 'up',
#  'version': '1.32',
#  'time': 1589813611693,
#  'currentMonthAPICalls': 9422187743}

# %% [markdown]
# # Historical prices endpoint

# %%
resp = requests.get(base_url+'/stock/AAPL/chart', params=params)

# %%
resp.raise_for_status()

# %%
resp.json()
# Out:
# [{'date': '2020-04-16',
#   'open': 287.38,
#   'close': 286.69,
#   'high': 288.2,
#   'low': 282.35,
#   'volume': 39281290,
#   'uOpen': 287.38,
#   'uClose': 286.69,
#   'uHigh': 288.2,
#   'uLow': 282.35,
#   'uVolume': 39281290,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Apr 16',
#   'changeOverTime': 0},
#  {'date': '2020-04-17',
#   'open': 284.69,
#   'close': 282.8,
#   'high': 286.95,
#   'low': 276.86,
#   'volume': 53812478,
#   'uOpen': 284.69,
#   'uClose': 282.8,
#   'uHigh': 286.95,
#   'uLow': 276.86,
#   'uVolume': 53812478,
#   'change': -3.89,
#   'changePercent': -1.3569,
#   'label': 'Apr 17',
#   'changeOverTime': -0.013569},
#  {'date': '2020-04-20',
#   'open': 277.95,
#   'close': 276.93,
#   'high': 281.68,
#   'low': 276.85,
#   'volume': 32503750,
#   'uOpen': 277.95,
#   'uClose': 276.93,
#   'uHigh': 281.68,
#   'uLow': 276.85,
#   'uVolume': 32503750,
#   'change': -5.87,
#   'changePercent': -2.0757,
#   'label': 'Apr 20',
#   'changeOverTime': -0.034044},
#  {'date': '2020-04-21',
#   'open': 276.28,
#   'close': 268.37,
#   'high': 277.25,
#   'low': 265.43,
#   'volume': 45247893,
#   'uOpen': 276.28,
#   'uClose': 268.37,
#   'uHigh': 277.25,
#   'uLow': 265.43,
#   'uVolume': 45247893,
#   'change': -8.56,
#   'changePercent': -3.091,
#   'label': 'Apr 21',
#   'changeOverTime': -0.063902},
#  {'date': '2020-04-22',
#   'open': 273.61,
#   'close': 276.1,
#   'high': 277.9,
#   'low': 272.2,
#   'volume': 29264342,
#   'uOpen': 273.61,
#   'uClose': 276.1,
#   'uHigh': 277.9,
#   'uLow': 272.2,
#   'uVolume': 29264342,
#   'change': 7.73,
#   'changePercent': 2.8804,
#   'label': 'Apr 22',
#   'changeOverTime': -0.036939},
#  {'date': '2020-04-23',
#   'open': 275.87,
#   'close': 275.03,
#   'high': 281.75,
#   'low': 274.87,
#   'volume': 31203582,
#   'uOpen': 275.87,
#   'uClose': 275.03,
#   'uHigh': 281.75,
#   'uLow': 274.87,
#   'uVolume': 31203582,
#   'change': -1.07,
#   'changePercent': -0.3875,
#   'label': 'Apr 23',
#   'changeOverTime': -0.040671},
#  {'date': '2020-04-24',
#   'open': 277.2,
#   'close': 282.97,
#   'high': 283.01,
#   'low': 277,
#   'volume': 31627183,
#   'uOpen': 277.2,
#   'uClose': 282.97,
#   'uHigh': 283.01,
#   'uLow': 277,
#   'uVolume': 31627183,
#   'change': 7.94,
#   'changePercent': 2.887,
#   'label': 'Apr 24',
#   'changeOverTime': -0.012976},
#  {'date': '2020-04-27',
#   'open': 281.8,
#   'close': 283.17,
#   'high': 284.54,
#   'low': 279.95,
#   'volume': 29271893,
#   'uOpen': 281.8,
#   'uClose': 283.17,
#   'uHigh': 284.54,
#   'uLow': 279.95,
#   'uVolume': 29271893,
#   'change': 0.2,
#   'changePercent': 0.0707,
#   'label': 'Apr 27',
#   'changeOverTime': -0.012278},
#  {'date': '2020-04-28',
#   'open': 285.08,
#   'close': 278.58,
#   'high': 285.83,
#   'low': 278.2,
#   'volume': 28001187,
#   'uOpen': 285.08,
#   'uClose': 278.58,
#   'uHigh': 285.83,
#   'uLow': 278.2,
#   'uVolume': 28001187,
#   'change': -4.59,
#   'changePercent': -1.6209,
#   'label': 'Apr 28',
#   'changeOverTime': -0.028288},
#  {'date': '2020-04-29',
#   'open': 284.73,
#   'close': 287.73,
#   'high': 289.67,
#   'low': 283.89,
#   'volume': 34320204,
#   'uOpen': 284.73,
#   'uClose': 287.73,
#   'uHigh': 289.67,
#   'uLow': 283.89,
#   'uVolume': 34320204,
#   'change': 9.15,
#   'changePercent': 3.2845,
#   'label': 'Apr 29',
#   'changeOverTime': 0.003628},
#  {'date': '2020-04-30',
#   'open': 289.96,
#   'close': 293.8,
#   'high': 294.53,
#   'low': 288.35,
#   'volume': 45765968,
#   'uOpen': 289.96,
#   'uClose': 293.8,
#   'uHigh': 294.53,
#   'uLow': 288.35,
#   'uVolume': 45765968,
#   'change': 6.07,
#   'changePercent': 2.1096,
#   'label': 'Apr 30',
#   'changeOverTime': 0.0248},
#  {'date': '2020-05-01',
#   'open': 286.25,
#   'close': 289.07,
#   'high': 299,
#   'low': 285.85,
#   'volume': 60154175,
#   'uOpen': 286.25,
#   'uClose': 289.07,
#   'uHigh': 299,
#   'uLow': 285.85,
#   'uVolume': 60154175,
#   'change': -4.73,
#   'changePercent': -1.6099,
#   'label': 'May 1',
#   'changeOverTime': 0.008302},
#  {'date': '2020-05-04',
#   'open': 289.17,
#   'close': 293.16,
#   'high': 293.69,
#   'low': 286.32,
#   'volume': 33391986,
#   'uOpen': 289.17,
#   'uClose': 293.16,
#   'uHigh': 293.69,
#   'uLow': 286.32,
#   'uVolume': 33391986,
#   'change': 4.09,
#   'changePercent': 1.4149,
#   'label': 'May 4',
#   'changeOverTime': 0.022568},
#  {'date': '2020-05-05',
#   'open': 295.06,
#   'close': 297.56,
#   'high': 301,
#   'low': 294.46,
#   'volume': 36937795,
#   'uOpen': 295.06,
#   'uClose': 297.56,
#   'uHigh': 301,
#   'uLow': 294.46,
#   'uVolume': 36937795,
#   'change': 4.4,
#   'changePercent': 1.5009,
#   'label': 'May 5',
#   'changeOverTime': 0.037916},
#  {'date': '2020-05-06',
#   'open': 300.46,
#   'close': 300.63,
#   'high': 303.24,
#   'low': 298.87,
#   'volume': 35583438,
#   'uOpen': 300.46,
#   'uClose': 300.63,
#   'uHigh': 303.24,
#   'uLow': 298.87,
#   'uVolume': 35583438,
#   'change': 3.07,
#   'changePercent': 1.0317,
#   'label': 'May 6',
#   'changeOverTime': 0.048624},
#  {'date': '2020-05-07',
#   'open': 303.22,
#   'close': 303.74,
#   'high': 305.17,
#   'low': 301.97,
#   'volume': 28803764,
#   'uOpen': 303.22,
#   'uClose': 303.74,
#   'uHigh': 305.17,
#   'uLow': 301.97,
#   'uVolume': 28803764,
#   'change': 3.11,
#   'changePercent': 1.0345,
#   'label': 'May 7',
#   'changeOverTime': 0.059472},
#  {'date': '2020-05-08',
#   'open': 305.64,
#   'close': 310.13,
#   'high': 310.35,
#   'low': 304.29,
#   'volume': 33511985,
#   'uOpen': 305.64,
#   'uClose': 310.13,
#   'uHigh': 310.35,
#   'uLow': 304.29,
#   'uVolume': 33511985,
#   'change': 6.39,
#   'changePercent': 2.1038,
#   'label': 'May 8',
#   'changeOverTime': 0.081761},
#  {'date': '2020-05-11',
#   'open': 308.1,
#   'close': 315.01,
#   'high': 317.05,
#   'low': 307.24,
#   'volume': 36486561,
#   'uOpen': 308.1,
#   'uClose': 315.01,
#   'uHigh': 317.05,
#   'uLow': 307.24,
#   'uVolume': 36486561,
#   'change': 4.88,
#   'changePercent': 1.5735,
#   'label': 'May 11',
#   'changeOverTime': 0.098783},
#  {'date': '2020-05-12',
#   'open': 317.83,
#   'close': 311.41,
#   'high': 319.69,
#   'low': 310.91,
#   'volume': 40575263,
#   'uOpen': 317.83,
#   'uClose': 311.41,
#   'uHigh': 319.69,
#   'uLow': 310.91,
#   'uVolume': 40575263,
#   'change': -3.6,
#   'changePercent': -1.1428,
#   'label': 'May 12',
#   'changeOverTime': 0.086226},
#  {'date': '2020-05-13',
#   'open': 312.15,
#   'close': 307.65,
#   'high': 315.95,
#   'low': 303.21,
#   'volume': 50155639,
#   'uOpen': 312.15,
#   'uClose': 307.65,
#   'uHigh': 315.95,
#   'uLow': 303.21,
#   'uVolume': 50155639,
#   'change': -3.76,
#   'changePercent': -1.2074,
#   'label': 'May 13',
#   'changeOverTime': 0.07311},
#  {'date': '2020-05-14',
#   'open': 304.51,
#   'close': 309.54,
#   'high': 309.79,
#   'low': 301.53,
#   'volume': 39732269,
#   'uOpen': 304.51,
#   'uClose': 309.54,
#   'uHigh': 309.79,
#   'uLow': 301.53,
#   'uVolume': 39732269,
#   'change': 1.89,
#   'changePercent': 0.6143,
#   'label': 'May 14',
#   'changeOverTime': 0.079703},
#  {'date': '2020-05-15',
#   'open': 300.35,
#   'close': 307.71,
#   'high': 307.9,
#   'low': 300.21,
#   'volume': 41587094,
#   'uOpen': 300.35,
#   'uClose': 307.71,
#   'uHigh': 307.9,
#   'uLow': 300.21,
#   'uVolume': 41587094,
#   'change': -1.83,
#   'changePercent': -0.5912,
#   'label': 'May 15',
#   'changeOverTime': 0.07332}]

# %% [markdown]
# # Converting response to a Pandas DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame(resp.json())

# %%
df.head()
# Out:
#          date    open   close    high     low    volume   uOpen  uClose  \
# 0  2020-04-16  287.38  286.69  288.20  282.35  39281290  287.38  286.69
# 1  2020-04-17  284.69  282.80  286.95  276.86  53812478  284.69  282.80
# 2  2020-04-20  277.95  276.93  281.68  276.85  32503750  277.95  276.93
# 3  2020-04-21  276.28  268.37  277.25  265.43  45247893  276.28  268.37
# 4  2020-04-22  273.61  276.10  277.90  272.20  29264342  273.61  276.10
#
#     uHigh    uLow   uVolume  change  changePercent   label  changeOverTime
# 0  288.20  282.35  39281290    0.00         0.0000  Apr 16        0.000000
# 1  286.95  276.86  53812478   -3.89        -1.3569  Apr 17       -0.013569
# 2  281.68  276.85  32503750   -5.87        -2.0757  Apr 20       -0.034044
# 3  277.25  265.43  45247893   -8.56        -3.0910  Apr 21       -0.063902
# 4  277.90  272.20  29264342    7.73         2.8804  Apr 22       -0.036939

# %% [markdown]
# # Create a function to access historical data

# %%
def historical_data(_symbol, _range=None, _date=None):
    endpoint = f'{base_url}/stock/{_symbol}/chart'
    if _range:
        endpoint += f'/{_range}'
    elif _date:
        endpoint += f'/date/{_date}'
    
    resp = requests.get(endpoint, params=params)
    resp.raise_for_status()
    return pd.DataFrame(resp.json())

# %%
appl_3m_df = historical_data('AAPL', _range='3m')

# %%
appl_3m_df.head()
# Out:
#          date    open   close    high     low    volume   uOpen  uClose  \
# 0  2020-02-18  315.36  319.00  319.75  314.61  38190545  315.36  319.00
# 1  2020-02-19  320.00  323.62  324.57  320.00  23495991  320.00  323.62
# 2  2020-02-20  322.63  320.30  324.65  318.21  25141489  322.63  320.30
# 3  2020-02-21  318.62  313.05  320.45  310.50  32426415  318.62  313.05
# 4  2020-02-24  297.26  298.18  304.18  289.23  55548828  297.26  298.18
#
#     uHigh    uLow   uVolume  change  changePercent       label  changeOverTime
# 0  319.75  314.61  38190545    0.00         0.0000  Feb 18, 20        0.000000
# 1  324.57  320.00  23495991    4.62         1.4483  Feb 19, 20        0.014483
# 2  324.65  318.21  25141489   -3.32        -1.0259  Feb 20, 20        0.004075
# 3  320.45  310.50  32426415   -7.25        -2.2635  Feb 21, 20       -0.018652
# 4  304.18  289.23  55548828  -14.87        -4.7500  Feb 24, 20       -0.065266

# %%
appl_april_20_df = historical_data('AAPL', _date=20200420)

# %%
appl_april_20_df
# Out:
#            date minute     label     high      low  average  volume  \
# 0    2020-04-20  09:30  09:30 AM  279.505  277.650  278.606   11364
# 1    2020-04-20  09:31  09:31 AM  279.270  279.005  279.121    5963
# 2    2020-04-20  09:32  09:32 AM  279.860  279.260  279.562    1982
# 3    2020-04-20  09:33  09:33 AM  279.960  279.480  279.643    2008
# 4    2020-04-20  09:34  09:34 AM  280.070  279.210  279.503    2043
# ..          ...    ...       ...      ...      ...      ...     ...
# 385  2020-04-20  15:55   3:55 PM  277.670  277.455  277.489    7307
# 386  2020-04-20  15:56   3:56 PM  277.955  277.500  277.786    1028
# 387  2020-04-20  15:57   3:57 PM  277.540  277.105  277.249    7081
# 388  2020-04-20  15:58   3:58 PM  277.630  277.110  277.332    3796
# 389  2020-04-20  15:59   3:59 PM  277.480  276.890  277.086    8705
#
#         notional  numberOfTrades  marketHigh  ...  marketAverage  \
# 0    3166076.120              90      279.54  ...        278.135
# 1    1664398.140              29      279.35  ...        279.077
# 2     554092.255              21      279.86  ...        279.519
# 3     561522.530              20      280.25  ...        279.844
# 4     571024.400              27      280.09  ...        279.555
# ..           ...             ...         ...  ...            ...
# 385  2027609.810              27      277.76  ...        277.557
# 386   285564.560              15      277.98  ...        277.757
# 387  1963201.695              50      277.56  ...        277.305
# 388  1052752.960              48      277.66  ...        277.366
# 389  2412035.685              97      277.53  ...        277.099
#
#      marketVolume  marketNotional  marketNumberOfTrades     open    close  \
# 0          956760    2.661086e+08                  2123  277.825  278.990
# 1          131855    3.679770e+07                   733  279.220  279.265
# 2          187639    5.244862e+07                   862  279.790  279.655
# 3          198354    5.550813e+07                   854  279.565  279.860
# 4          156065    4.362882e+07                   788  280.070  279.575
# ..            ...             ...                   ...      ...      ...
# 385        177341    4.922221e+07                   954  277.520  277.590
# 386        136318    3.786322e+07                   721  277.660  277.500
# 387        157274    4.361281e+07                   950  277.500  277.280
# 388        203075    5.632612e+07                  1220  277.320  277.370
# 389        341880    9.473456e+07                  1953  277.480  276.890
#
#      marketOpen  marketClose  changeOverTime  marketChangeOverTime
# 0       277.950      278.709        0.000000              0.000000
# 1       278.623      279.270        0.001848              0.003387
# 2       279.280      279.510        0.003431              0.004976
# 3       279.580      280.100        0.003722              0.006144
# 4       280.090      279.630        0.003220              0.005105
# ..          ...          ...             ...                   ...
# 385     277.660      277.640       -0.004009             -0.002078
# 386     277.660      277.522       -0.002943             -0.001359
# 387     277.510      277.267       -0.004871             -0.002984
# 388     277.280      277.370       -0.004573             -0.002765
# 389     277.380      276.850       -0.005456             -0.003725
#
# [390 rows x 21 columns]

# %% [markdown]
# # Using the sandbox environment

# %%
''' This requires a new sandbox token. You can save it as an environment variable (recommended)
or hard code it. You will also need to activate the sanbox environment from within the IEX console.'''

sandbox_params = {'token': 'your_sandbox_api_token'} 
resp = requests.get(sandbox_url+'/stock/AAPL/chart', params=sandbox_params)

# %%
resp.raise_for_status()

# %%
resp.json()
# Out:
# [{'date': '2020-04-16',
#   'open': 301.01,
#   'close': 291.57,
#   'high': 290.4,
#   'low': 286.83,
#   'volume': 40026236,
#   'uOpen': 300.62,
#   'uClose': 289.78,
#   'uHigh': 299,
#   'uLow': 289.63,
#   'uVolume': 41087409,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Apr 16',
#   'changeOverTime': 0},
#  {'date': '2020-04-17',
#   'open': 293.06,
#   'close': 289.5,
#   'high': 287.3,
#   'low': 289.43,
#   'volume': 56393994,
#   'uOpen': 290.58,
#   'uClose': 286.7,
#   'uHigh': 290.33,
#   'uLow': 287.1,
#   'uVolume': 55269258,
#   'change': -3.9,
#   'changePercent': -1.3999,
#   'label': 'Apr 17',
#   'changeOverTime': -0.014096},
#  {'date': '2020-04-20',
#   'open': 288.84,
#   'close': 282.8,
#   'high': 288.6,
#   'low': 284.64,
#   'volume': 32746091,
#   'uOpen': 288.35,
#   'uClose': 277.83,
#   'uHigh': 288.3,
#   'uLow': 283.74,
#   'uVolume': 33528584,
#   'change': -6.02,
#   'changePercent': -2.1512,
#   'label': 'Apr 20',
#   'changeOverTime': -0.035259},
#  {'date': '2020-04-21',
#   'open': 289.54,
#   'close': 269.12,
#   'high': 280.76,
#   'low': 268.12,
#   'volume': 46005495,
#   'uOpen': 278.81,
#   'uClose': 279.37,
#   'uHigh': 287.69,
#   'uLow': 274.56,
#   'uVolume': 47408607,
#   'change': -8.97,
#   'changePercent': -3.107,
#   'label': 'Apr 21',
#   'changeOverTime': -0.064012},
#  {'date': '2020-04-22',
#   'open': 287.09,
#   'close': 284.5,
#   'high': 290.4,
#   'low': 281.9,
#   'volume': 29437731,
#   'uOpen': 277.21,
#   'uClose': 288.8,
#   'uHigh': 280.3,
#   'uLow': 280.2,
#   'uVolume': 29321858,
#   'change': 7.78,
#   'changePercent': 2.963,
#   'label': 'Apr 22',
#   'changeOverTime': -0.037623},
#  {'date': '2020-04-23',
#   'open': 276.77,
#   'close': 284.84,
#   'high': 282.03,
#   'low': 280.79,
#   'volume': 31418692,
#   'uOpen': 286.85,
#   'uClose': 279.86,
#   'uHigh': 287.72,
#   'uLow': 277.11,
#   'uVolume': 31442909,
#   'change': -1.1,
#   'changePercent': -0.3954,
#   'label': 'Apr 23',
#   'changeOverTime': -0.042118},
#  {'date': '2020-04-24',
#   'open': 278.1,
#   'close': 284.57,
#   'high': 291.07,
#   'low': 279,
#   'volume': 31790914,
#   'uOpen': 290.4,
#   'uClose': 290.79,
#   'uHigh': 285.68,
#   'uLow': 289,
#   'uVolume': 32598491,
#   'change': 8.21,
#   'changePercent': 2.905,
#   'label': 'Apr 24',
#   'changeOverTime': -0.012986},
#  {'date': '2020-04-27',
#   'open': 286.1,
#   'close': 284.21,
#   'high': 296.69,
#   'low': 293.34,
#   'volume': 30412106,
#   'uOpen': 290.5,
#   'uClose': 285.81,
#   'uHigh': 292.79,
#   'uLow': 288.16,
#   'uVolume': 30294627,
#   'change': 0.2,
#   'changePercent': 0.0739,
#   'label': 'Apr 27',
#   'changeOverTime': -0.012683},
#  {'date': '2020-04-28',
#   'open': 294,
#   'close': 280.15,
#   'high': 299.86,
#   'low': 279.1,
#   'volume': 29347158,
#   'uOpen': 296.05,
#   'uClose': 279.55,
#   'uHigh': 291.36,
#   'uLow': 288.2,
#   'uVolume': 28574446,
#   'change': -4.67,
#   'changePercent': -1.6266,
#   'label': 'Apr 28',
#   'changeOverTime': -0.028741},
#  {'date': '2020-04-29',
#   'open': 290.72,
#   'close': 301.21,
#   'high': 299.09,
#   'low': 292.54,
#   'volume': 35232215,
#   'uOpen': 293.65,
#   'uClose': 299.05,
#   'uHigh': 301.16,
#   'uLow': 296.64,
#   'uVolume': 34669835,
#   'change': 9.42,
#   'changePercent': 3.3022,
#   'label': 'Apr 29',
#   'changeOverTime': 0.003661},
#  {'date': '2020-04-30',
#   'open': 302.9,
#   'close': 303.5,
#   'high': 301.35,
#   'low': 299.06,
#   'volume': 46690066,
#   'uOpen': 295.46,
#   'uClose': 296.5,
#   'uHigh': 296.4,
#   'uLow': 291.54,
#   'uVolume': 46922296,
#   'change': 6.25,
#   'changePercent': 2.1911,
#   'label': 'Apr 30',
#   'changeOverTime': 0.0253},
#  {'date': '2020-05-01',
#   'open': 287.12,
#   'close': 292.99,
#   'high': 312,
#   'low': 291.39,
#   'volume': 62362044,
#   'uOpen': 288.76,
#   'uClose': 292.92,
#   'uHigh': 303,
#   'uLow': 291.88,
#   'uVolume': 61971030,
#   'change': -4.97,
#   'changePercent': -1.6882,
#   'label': 'May 1',
#   'changeOverTime': 0.00841},
#  {'date': '2020-05-04',
#   'open': 297.29,
#   'close': 298.42,
#   'high': 298.67,
#   'low': 298.47,
#   'volume': 33769068,
#   'uOpen': 299.63,
#   'uClose': 296.61,
#   'uHigh': 300.33,
#   'uLow': 286.56,
#   'uVolume': 34822349,
#   'change': 4.22,
#   'changePercent': 1.4295,
#   'label': 'May 4',
#   'changeOverTime': 0.023501},
#  {'date': '2020-05-05',
#   'open': 304.19,
#   'close': 300.84,
#   'high': 308,
#   'low': 307.69,
#   'volume': 38566770,
#   'uOpen': 303.1,
#   'uClose': 305.58,
#   'uHigh': 315,
#   'uLow': 295.42,
#   'uVolume': 37692938,
#   'change': 4.6,
#   'changePercent': 1.5609,
#   'label': 'May 5',
#   'changeOverTime': 0.038859},
#  {'date': '2020-05-06',
#   'open': 313.82,
#   'close': 311.69,
#   'high': 312.19,
#   'low': 309.33,
#   'volume': 37279836,
#   'uOpen': 306.35,
#   'uClose': 313.84,
#   'uHigh': 309.6,
#   'uLow': 312.87,
#   'uVolume': 36504321,
#   'change': 3.15,
#   'changePercent': 1.0516,
#   'label': 'May 6',
#   'changeOverTime': 0.050255},
#  {'date': '2020-05-07',
#   'open': 305.12,
#   'close': 306.67,
#   'high': 312.48,
#   'low': 302.98,
#   'volume': 29960999,
#   'uOpen': 304.23,
#   'uClose': 307.83,
#   'uHigh': 317.04,
#   'uLow': 303,
#   'uVolume': 28868206,
#   'change': 3.12,
#   'changePercent': 1.0715,
#   'label': 'May 7',
#   'changeOverTime': 0.06111},
#  {'date': '2020-05-08',
#   'open': 313.42,
#   'close': 323.03,
#   'high': 316.05,
#   'low': 309.59,
#   'volume': 33781020,
#   'uOpen': 316.19,
#   'uClose': 317.45,
#   'uHigh': 324.05,
#   'uLow': 314.78,
#   'uVolume': 34618573,
#   'change': 6.58,
#   'changePercent': 2.1897,
#   'label': 'May 8',
#   'changeOverTime': 0.08504},
#  {'date': '2020-05-11',
#   'open': 317.2,
#   'close': 321.4,
#   'high': 324.62,
#   'low': 309.74,
#   'volume': 37081726,
#   'uOpen': 312.9,
#   'uClose': 315.76,
#   'uHigh': 318.28,
#   'uLow': 307.7,
#   'uVolume': 37178450,
#   'change': 5.04,
#   'changePercent': 1.6425,
#   'label': 'May 11',
#   'changeOverTime': 0.099999},
#  {'date': '2020-05-12',
#   'open': 324.75,
#   'close': 313.9,
#   'high': 329.94,
#   'low': 324.24,
#   'volume': 41240516,
#   'uOpen': 322.15,
#   'uClose': 311.73,
#   'uHigh': 325.17,
#   'uLow': 322.58,
#   'uVolume': 41940317,
#   'change': -3.7,
#   'changePercent': -1.1733,
#   'label': 'May 12',
#   'changeOverTime': 0.087058},
#  {'date': '2020-05-13',
#   'open': 326.45,
#   'close': 308.18,
#   'high': 328.31,
#   'low': 310.29,
#   'volume': 51403014,
#   'uOpen': 315.27,
#   'uClose': 312.79,
#   'uHigh': 330.23,
#   'uLow': 315.07,
#   'uVolume': 51763512,
#   'change': -3.84,
#   'changePercent': -1.264,
#   'label': 'May 13',
#   'changeOverTime': 0.07656},
#  {'date': '2020-05-14',
#   'open': 311.8,
#   'close': 322.01,
#   'high': 321.88,
#   'low': 315.7,
#   'volume': 41622116,
#   'uOpen': 308.66,
#   'uClose': 317.92,
#   'uHigh': 322.45,
#   'uLow': 309.23,
#   'uVolume': 40673015,
#   'change': 1.98,
#   'changePercent': 0.6278,
#   'label': 'May 14',
#   'changeOverTime': 0.082057},
#  {'date': '2020-05-15',
#   'open': 303.6,
#   'close': 316.84,
#   'high': 318.8,
#   'low': 307.16,
#   'volume': 41802064,
#   'uOpen': 309.88,
#   'uClose': 317.88,
#   'uHigh': 321.9,
#   'uLow': 312.73,
#   'uVolume': 43516284,
#   'change': -1.9,
#   'changePercent': -0.5998,
#   'label': 'May 15',
#   'changeOverTime': 0.07643}]

# %% [markdown]
# # Earnings Today

# %%
endpoint = '/stock/market/today-earnings'
resp = requests.get(base_url+endpoint, params=params)

# %%
resp.raise_for_status()

# %%
resp.json()
# Out:
# {'bto': [{'consensusEPS': -0.41,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'SFTBY',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'SFTBY',
#     'companyName': 'SoftBank Group Corp.',
#     'primaryExchange': 'US OTC',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': 21.92,
#     'highTime': 1589812765245,
#     'highSource': '15 minute delayed price',
#     'low': 21.42,
#     'lowTime': 1589808991542,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 21.16,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 15, 2020',
#     'latestUpdate': 1589515200000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 21.16,
#     'previousVolume': 536790,
#     'change': 0,
#     'changePercent': 0,
#     'volume': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 924488,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': None,
#     'iexCloseTime': None,
#     'marketCap': 87654778279,
#     'peRatio': 31.99,
#     'week52High': 27.38,
#     'week52Low': 12.2,
#     'ytdChange': -0.0253,
#     'lastTradeTime': 1589812756015}},
#   {'consensusEPS': -0.35,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 7,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'SE',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'SE',
#     'companyName': 'Sea Ltd. (Singapore)',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813612356,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808602118,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 68.625,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:22 AM',
#     'latestUpdate': 1589813662633,
#     'latestVolume': None,
#     'iexRealtimePrice': 68.625,
#     'iexRealtimeSize': 300,
#     'iexLastUpdated': 1589813662633,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 61.96,
#     'previousVolume': 6439561,
#     'change': 6.665,
#     'changePercent': 0.10757,
#     'volume': None,
#     'iexMarketPercent': 0.0411632110969107,
#     'iexVolume': 172990,
#     'avgTotalVolume': 3946396,
#     'iexBidPrice': 65.75,
#     'iexBidSize': 500,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 68.56,
#     'iexCloseTime': 1589813662080,
#     'marketCap': 21541420234,
#     'peRatio': -19.23,
#     'week52High': 64.39,
#     'week52Low': 24.59,
#     'ytdChange': 0.61877,
#     'lastTradeTime': 1589813662633,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.35,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'KMTUY',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'KMTUY',
#     'companyName': 'Komatsu Ltd.',
#     'primaryExchange': 'US OTC',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': 19.15,
#     'highTime': 1589812674915,
#     'highSource': '15 minute delayed price',
#     'low': 18.9,
#     'lowTime': 1589808605491,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 19.08,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 15, 2020',
#     'latestUpdate': 1589515200000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 19.08,
#     'previousVolume': 53585,
#     'change': 0,
#     'changePercent': 0,
#     'volume': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 247179,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': None,
#     'iexCloseTime': None,
#     'marketCap': 18019020043,
#     'peRatio': 9.48,
#     'week52High': 25.35,
#     'week52Low': 13.38,
#     'ytdChange': -0.2414,
#     'lastTradeTime': 1589812227145}},
#   {'consensusEPS': 0.08,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 4,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'PCRFY',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'PCRFY',
#     'companyName': 'Panasonic Corp.',
#     'primaryExchange': 'US OTC',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': 7.75,
#     'highTime': 1589812705111,
#     'highSource': '15 minute delayed price',
#     'low': 7.29,
#     'lowTime': 1589808602052,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 7.35,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 15, 2020',
#     'latestUpdate': 1589515200000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 7.35,
#     'previousVolume': 477995,
#     'change': 0,
#     'changePercent': 0,
#     'volume': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 237057,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': None,
#     'iexCloseTime': None,
#     'marketCap': 17146543315,
#     'peRatio': 6.49,
#     'week52High': 11.77,
#     'week52Low': 6.19,
#     'ytdChange': -0.2105,
#     'lastTradeTime': 1589812704313}},
#   {'actualEPS': 0.35234,
#    'consensusEPS': 0.34,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 5,
#    'EPSSurpriseDollar': 0.01,
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': 0.176092,
#    'yearAgoChangePercent': 1.0009,
#    'symbol': 'FUJHY',
#    'currency': 'USD',
#    'quote': {'symbol': 'FUJHY',
#     'companyName': 'Subaru Corp.',
#     'primaryExchange': 'US OTC',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': 10.085,
#     'highTime': 1589812730008,
#     'highSource': '15 minute delayed price',
#     'low': 9.86,
#     'lowTime': 1589808605062,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 9.87,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 15, 2020',
#     'latestUpdate': 1589515200000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 9.87,
#     'previousVolume': 72935,
#     'change': 0,
#     'changePercent': 0,
#     'volume': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 109969,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': None,
#     'iexCloseTime': None,
#     'marketCap': 15136948709,
#     'peRatio': 11.74,
#     'week52High': 14.51,
#     'week52Low': 7.61,
#     'ytdChange': -0.2072,
#     'lastTradeTime': 1589812193136}},
#   {'actualEPS': -1.2993,
#    'consensusEPS': -1.54,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 6,
#    'EPSSurpriseDollar': 0.24,
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': -0.838613,
#    'yearAgoChangePercent': -0.5493,
#    'symbol': 'RYAAY',
#    'currency': 'USD',
#    'quote': {'symbol': 'RYAAY',
#     'companyName': 'Ryanair Holdings Plc',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812765524,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589808917244,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 56.69,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:24 AM',
#     'latestUpdate': 1589813664709,
#     'latestVolume': None,
#     'iexRealtimePrice': 56.69,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813664709,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 49.75,
#     'previousVolume': 807343,
#     'change': 6.94,
#     'changePercent': 0.1395,
#     'volume': None,
#     'iexMarketPercent': 0.04915626653658792,
#     'iexVolume': 22573,
#     'avgTotalVolume': 632204,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 56.69,
#     'iexCloseTime': 1589813664709,
#     'marketCap': 12349122840,
#     'peRatio': 10.97,
#     'week52High': 96.79,
#     'week52Low': 44.44,
#     'ytdChange': -0.2974,
#     'lastTradeTime': 1589813664709,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.11,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'ASGLY',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'ASGLY',
#     'companyName': 'AGC, Inc. (Japan)',
#     'primaryExchange': 'US OTC',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': 4.95,
#     'highTime': 1589812216955,
#     'highSource': '15 minute delayed price',
#     'low': 4.9,
#     'lowTime': 1589812067067,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 4.87,
#     'latestSource': 'Previous close',
#     'latestTime': 'May 15, 2020',
#     'latestUpdate': 1589515200000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 4.87,
#     'previousVolume': 49024,
#     'change': 0,
#     'changePercent': 0,
#     'volume': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 104741,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': None,
#     'iexCloseTime': None,
#     'marketCap': 5395237536,
#     'peRatio': 13.31,
#     'week52High': 7.54,
#     'week52Low': 4.13,
#     'ytdChange': -0.3208,
#     'lastTradeTime': 1589812216955}},
#   {'actualEPS': -5.36,
#    'announceTime': 'BTO',
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'MSGE',
#    'quote': {'symbol': 'MSGE',
#     'companyName': 'Madison Square Garden Entertainment Corp.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812758781,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589811640060,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 79.93,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:49:39 AM',
#     'latestUpdate': 1589813379586,
#     'latestVolume': None,
#     'iexRealtimePrice': 79.93,
#     'iexRealtimeSize': 21,
#     'iexLastUpdated': 1589813379586,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 78.49,
#     'previousVolume': 240663,
#     'change': 1.44,
#     'changePercent': 0.01835,
#     'volume': None,
#     'iexMarketPercent': 0.028413103177716753,
#     'iexVolume': 2897,
#     'avgTotalVolume': 371297,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': 93.9,
#     'iexOpenTime': 1587389406024,
#     'iexClose': 79.93,
#     'iexCloseTime': 1589813379586,
#     'marketCap': 1917641954,
#     'peRatio': None,
#     'week52High': 100,
#     'week52Low': 58.67,
#     'ytdChange': -0.19675,
#     'lastTradeTime': 1589813379586,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.96,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'SY',
#    'reportDate': '2020-05-18',
#    'currency': 'CNY',
#    'quote': {'symbol': 'SY',
#     'companyName': 'So-Young International, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813572406,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808799299,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 11.17,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:52:52 AM',
#     'latestUpdate': 1589813572406,
#     'latestVolume': None,
#     'iexRealtimePrice': 11.17,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813572406,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 10.98,
#     'previousVolume': 756783,
#     'change': 0.19,
#     'changePercent': 0.0173,
#     'volume': None,
#     'iexMarketPercent': 0.01948397393270382,
#     'iexVolume': 12013,
#     'avgTotalVolume': 383255,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 11.45,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 11.17,
#     'iexCloseTime': 1589813572406,
#     'marketCap': 1007346411,
#     'peRatio': 60.12,
#     'week52High': 18.7,
#     'week52Low': 8.03,
#     'ytdChange': -0.079,
#     'lastTradeTime': 1589813572406,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.28,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 7,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'NAT',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'NAT',
#     'companyName': 'Nordic American Tankers Ltd.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812760049,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809465197,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 4.835,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:52:57 AM',
#     'latestUpdate': 1589813577559,
#     'latestVolume': None,
#     'iexRealtimePrice': 4.835,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813577559,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 5.03,
#     'previousVolume': 9048582,
#     'change': -0.195,
#     'changePercent': -0.03877,
#     'volume': None,
#     'iexMarketPercent': 0.0021103333431389225,
#     'iexVolume': 14850,
#     'avgTotalVolume': 18086623,
#     'iexBidPrice': 4.82,
#     'iexBidSize': 100,
#     'iexAskPrice': 5.1,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 4.835,
#     'iexCloseTime': 1589813577559,
#     'marketCap': 711861885,
#     'peRatio': -65.43,
#     'week52High': 9,
#     'week52Low': 1.66,
#     'ytdChange': -0.02257,
#     'lastTradeTime': 1589813577559,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.33,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'NIU',
#    'reportDate': '2020-05-18',
#    'currency': 'CNY',
#    'quote': {'symbol': 'NIU',
#     'companyName': 'Niu Technologies',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812724088,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809950668,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 9.13,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:45:33 AM',
#     'latestUpdate': 1589813133354,
#     'latestVolume': None,
#     'iexRealtimePrice': 9.13,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813133354,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 9.06,
#     'previousVolume': 147200,
#     'change': 0.07,
#     'changePercent': 0.00773,
#     'volume': None,
#     'iexMarketPercent': 0.017576938830275553,
#     'iexVolume': 2489,
#     'avgTotalVolume': 133133,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 9.4,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 9.13,
#     'iexCloseTime': 1589813133354,
#     'marketCap': 594248318,
#     'peRatio': -15.82,
#     'week52High': 10.1,
#     'week52Low': 5.33,
#     'ytdChange': 0.05393,
#     'lastTradeTime': 1589813133354,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.08,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 3,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'SOGO',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'SOGO',
#     'companyName': 'Sogou, Inc.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812753020,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809356541,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 3.395,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:49:45 AM',
#     'latestUpdate': 1589813385376,
#     'latestVolume': None,
#     'iexRealtimePrice': 3.395,
#     'iexRealtimeSize': 10,
#     'iexLastUpdated': 1589813385376,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 3.51,
#     'previousVolume': 863984,
#     'change': -0.115,
#     'changePercent': -0.03276,
#     'volume': None,
#     'iexMarketPercent': 0.007789170905169617,
#     'iexVolume': 6602,
#     'avgTotalVolume': 631158,
#     'iexBidPrice': 3.4,
#     'iexBidSize': 100,
#     'iexAskPrice': 3.42,
#     'iexAskSize': 200,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 3.395,
#     'iexCloseTime': 1589813385376,
#     'marketCap': 401969698,
#     'peRatio': 14.83,
#     'week52High': 5.8,
#     'week52Low': 3,
#     'ytdChange': -0.26136,
#     'lastTradeTime': 1589813385376,
#     'isUSMarketOpen': True}},
#   {'actualEPS': -0.47,
#    'consensusEPS': -0.71,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': 0.24,
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': -1.39,
#    'yearAgoChangePercent': 0.6619,
#    'symbol': 'SOHU',
#    'currency': 'USD',
#    'quote': {'symbol': 'SOHU',
#     'companyName': 'Sohu.com Ltd.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812748276,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809117699,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 8.41,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:49:03 AM',
#     'latestUpdate': 1589813343093,
#     'latestVolume': None,
#     'iexRealtimePrice': 8.41,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813343093,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 7.98,
#     'previousVolume': 448574,
#     'change': 0.43,
#     'changePercent': 0.05388,
#     'volume': None,
#     'iexMarketPercent': 0.029794004482486938,
#     'iexVolume': 11685,
#     'avgTotalVolume': 496146,
#     'iexBidPrice': 8.45,
#     'iexBidSize': 100,
#     'iexAskPrice': 8.65,
#     'iexAskSize': 300,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 8.41,
#     'iexCloseTime': 1589813343093,
#     'marketCap': 329912005,
#     'peRatio': -2.21,
#     'week52High': 18.5,
#     'week52Low': 5.41,
#     'ytdChange': -0.24672,
#     'lastTradeTime': 1589813343093,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 11,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'TRVG',
#    'reportDate': '2020-05-18',
#    'currency': 'EUR',
#    'quote': {'symbol': 'TRVG',
#     'companyName': 'trivago NV',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812741688,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589808955710,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 1.585,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:39:01 AM',
#     'latestUpdate': 1589812741687,
#     'latestVolume': None,
#     'iexRealtimePrice': 1.585,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589812741687,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 1.45,
#     'previousVolume': 309872,
#     'change': 0.135,
#     'changePercent': 0.0931,
#     'volume': None,
#     'iexMarketPercent': 0.003023126920945231,
#     'iexVolume': 900,
#     'avgTotalVolume': 286793,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 1.585,
#     'iexCloseTime': 1589812741687,
#     'marketCap': 80544479,
#     'peRatio': 26.51,
#     'week52High': 5.38,
#     'week52Low': 1.3,
#     'ytdChange': -0.3699,
#     'lastTradeTime': 1589812741687,
#     'isUSMarketOpen': True}},
#   {'actualEPS': 0.4,
#    'consensusEPS': -0.06,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 2,
#    'EPSSurpriseDollar': 0.46,
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': -3.13,
#    'yearAgoChangePercent': 1.1278,
#    'symbol': 'YCBD',
#    'currency': 'USD',
#    'quote': {'symbol': 'YCBD',
#     'companyName': 'cbdMD, Inc.',
#     'primaryExchange': 'NYSE American',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813274780,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589810308583,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 1.48,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:52:31 AM',
#     'latestUpdate': 1589813551368,
#     'latestVolume': None,
#     'iexRealtimePrice': 1.48,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813551368,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 0.97,
#     'previousVolume': 1155905,
#     'change': 0.51,
#     'changePercent': 0.52577,
#     'volume': None,
#     'iexMarketPercent': 0.0024654001653320297,
#     'iexVolume': 29591,
#     'avgTotalVolume': 872778,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 1.69,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 1.48,
#     'iexCloseTime': 1589813551368,
#     'marketCap': 75976688,
#     'peRatio': 10.8,
#     'week52High': 6.7,
#     'week52Low': 0.502,
#     'ytdChange': -0.05793000000000004,
#     'lastTradeTime': 1589813551368,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.63,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 4,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'INSE',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'INSE',
#     'companyName': 'Inspired Entertainment, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813651617,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808858558,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 2.535,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:11 AM',
#     'latestUpdate': 1589813651617,
#     'latestVolume': None,
#     'iexRealtimePrice': 2.535,
#     'iexRealtimeSize': 600,
#     'iexLastUpdated': 1589813651617,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 2.11,
#     'previousVolume': 248329,
#     'change': 0.425,
#     'changePercent': 0.20142,
#     'volume': None,
#     'iexMarketPercent': 0.004156696997747,
#     'iexVolume': 1904,
#     'avgTotalVolume': 341224,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 2.535,
#     'iexCloseTime': 1589813651617,
#     'marketCap': 58360263,
#     'peRatio': -1.14,
#     'week52High': 9.7,
#     'week52Low': 1.87,
#     'ytdChange': -0.48918,
#     'lastTradeTime': 1589813651617,
#     'isUSMarketOpen': True}},
#   {'actualEPS': -0.3,
#    'consensusEPS': -0.3,
#    'announceTime': 'BTO',
#    'numberOfEstimates': 1,
#    'EPSSurpriseDollar': 0,
#    'EPSReportDate': '2020-05-18',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'yearAgo': -0.67,
#    'yearAgoChangePercent': 0.5522,
#    'symbol': 'HZN',
#    'currency': 'USD',
#    'quote': {'symbol': 'HZN',
#     'companyName': 'Horizon Global Corp.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812746214,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589808600587,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 1.61,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:50:54 AM',
#     'latestUpdate': 1589813454538,
#     'latestVolume': None,
#     'iexRealtimePrice': 1.61,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813454538,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 1.46,
#     'previousVolume': 48064,
#     'change': 0.15,
#     'changePercent': 0.10274,
#     'volume': None,
#     'iexMarketPercent': 0.00405120725976341,
#     'iexVolume': 100,
#     'avgTotalVolume': 45536,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 1.61,
#     'iexCloseTime': 1589813454538,
#     'marketCap': 41010564,
#     'peRatio': -0.41,
#     'week52High': 5.79,
#     'week52Low': 1.2,
#     'ytdChange': -0.48246000000000006,
#     'lastTradeTime': 1589813454538,
#     'isUSMarketOpen': True}}],
#  'amc': [{'consensusEPS': 3.83,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 21,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'BIDU',
#    'reportDate': '2020-05-18',
#    'currency': 'CNY',
#    'quote': {'symbol': 'BIDU',
#     'companyName': 'Baidu, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813640065,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808602096,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 107.34,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:03 AM',
#     'latestUpdate': 1589813643006,
#     'latestVolume': None,
#     'iexRealtimePrice': 107.34,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813643006,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 99.86,
#     'previousVolume': 3355009,
#     'change': 7.48,
#     'changePercent': 0.0749,
#     'volume': None,
#     'iexMarketPercent': 0.025590542899812795,
#     'iexVolume': 60830,
#     'avgTotalVolume': 3958449,
#     'iexBidPrice': 103.89,
#     'iexBidSize': 100,
#     'iexAskPrice': 108.5,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 107.34,
#     'iexCloseTime': 1589813643006,
#     'marketCap': 29393529405,
#     'peRatio': 124.16,
#     'week52High': 155.45,
#     'week52Low': 82,
#     'ytdChange': -0.1539,
#     'lastTradeTime': 1589813643006,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.16,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 9,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'BILI',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'BILI',
#     'companyName': 'Bilibili, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812764684,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589808620973,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 32.185,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:02 AM',
#     'latestUpdate': 1589813642051,
#     'latestVolume': None,
#     'iexRealtimePrice': 32.185,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813642051,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 30.88,
#     'previousVolume': 5019220,
#     'change': 1.305,
#     'changePercent': 0.04226,
#     'volume': None,
#     'iexMarketPercent': 0.018764641610262645,
#     'iexVolume': 56983,
#     'avgTotalVolume': 4915759,
#     'iexBidPrice': 29.8,
#     'iexBidSize': 300,
#     'iexAskPrice': 32.45,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 32.185,
#     'iexCloseTime': 1589813642051,
#     'marketCap': 7812951910,
#     'peRatio': -56.23,
#     'week52High': 31.62,
#     'week52Low': 13.23,
#     'ytdChange': 0.6282599999999999,
#     'lastTradeTime': 1589813642051,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -3.61,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 16,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'IQ',
#    'reportDate': '2020-05-18',
#    'currency': 'CNY',
#    'quote': {'symbol': 'IQ',
#     'companyName': 'iQIYI, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812762989,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589813593659,
#     'lowSource': 'IEX real time price',
#     'latestPrice': 18.01,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:18 AM',
#     'latestUpdate': 1589813658685,
#     'latestVolume': None,
#     'iexRealtimePrice': 18.01,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813658685,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 17.95,
#     'previousVolume': 6759244,
#     'change': 0.06,
#     'changePercent': 0.00334,
#     'volume': None,
#     'iexMarketPercent': 0.010536271619834251,
#     'iexVolume': 38667,
#     'avgTotalVolume': 9657657,
#     'iexBidPrice': 18.02,
#     'iexBidSize': 100,
#     'iexAskPrice': 18.03,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 18.01,
#     'iexCloseTime': 1589813658685,
#     'marketCap': 5812406220,
#     'peRatio': -8.82,
#     'week52High': 27.5,
#     'week52Low': 14.51,
#     'ytdChange': -0.16335999999999998,
#     'lastTradeTime': 1589813658685,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.07,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'BVN',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'BVN',
#     'companyName': 'Compañía de Minas Buenaventura SAA',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812756791,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809643978,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 8.65,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:25 AM',
#     'latestUpdate': 1589813665472,
#     'latestVolume': None,
#     'iexRealtimePrice': 8.65,
#     'iexRealtimeSize': 80,
#     'iexLastUpdated': 1589813665472,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 8.35,
#     'previousVolume': 2891603,
#     'change': 0.3,
#     'changePercent': 0.03593,
#     'volume': None,
#     'iexMarketPercent': 0.03964681198507555,
#     'iexVolume': 39720,
#     'avgTotalVolume': 1907594,
#     'iexBidPrice': 8.59,
#     'iexBidSize': 100,
#     'iexAskPrice': 8.65,
#     'iexAskSize': 100,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 8.65,
#     'iexCloseTime': 1589813665472,
#     'marketCap': 2194634750,
#     'peRatio': -70.96,
#     'week52High': 17.85,
#     'week52Low': 5.12,
#     'ytdChange': -0.41686999999999996,
#     'lastTradeTime': 1589813665472,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 0.04,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'APLE',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'APLE',
#     'companyName': 'Apple Hospitality REIT, Inc.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589813658699,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808600640,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 9.135,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:18 AM',
#     'latestUpdate': 1589813658699,
#     'latestVolume': None,
#     'iexRealtimePrice': 9.135,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1589813658699,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 8.16,
#     'previousVolume': 2262762,
#     'change': 0.975,
#     'changePercent': 0.11949,
#     'volume': None,
#     'iexMarketPercent': 0.06752772041872228,
#     'iexVolume': 64031,
#     'avgTotalVolume': 3233595,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 9.135,
#     'iexCloseTime': 1589813658699,
#     'marketCap': 2040000795,
#     'peRatio': 11.9,
#     'week52High': 16.88,
#     'week52Low': 4.48,
#     'ytdChange': -0.37871,
#     'lastTradeTime': 1589813658699,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.7,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'GNFT',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'GNFT',
#     'companyName': 'Genfit SA',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812752498,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589813315582,
#     'lowSource': 'IEX real time price',
#     'latestPrice': 5.68,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:48:35 AM',
#     'latestUpdate': 1589813315582,
#     'latestVolume': None,
#     'iexRealtimePrice': 5.68,
#     'iexRealtimeSize': 86,
#     'iexLastUpdated': 1589813315582,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 5.78,
#     'previousVolume': 300507,
#     'change': -0.1,
#     'changePercent': -0.0173,
#     'volume': None,
#     'iexMarketPercent': 0.007701217794195911,
#     'iexVolume': 492,
#     'avgTotalVolume': 137333,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 5.68,
#     'iexCloseTime': 1589813315582,
#     'marketCap': 220558314,
#     'peRatio': -2.52,
#     'week52High': 24.85,
#     'week52Low': 5.62,
#     'ytdChange': -0.7411,
#     'lastTradeTime': 1589813315582,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': 1.19,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'DAC',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'DAC',
#     'companyName': 'Danaos Corp.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812736888,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809290575,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 3.81,
#     'latestSource': 'Previous close',
#     'latestTime': None,
#     'latestUpdate': 1589812454471,
#     'latestVolume': None,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 3.81,
#     'previousVolume': 92833,
#     'change': None,
#     'changePercent': None,
#     'volume': None,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 81098,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 3.78,
#     'iexCloseTime': 1589569404332,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': None,
#     'week52Low': None,
#     'ytdChange': None,
#     'lastTradeTime': 1589812454471,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.07,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'CVGI',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'CVGI',
#     'companyName': 'Commercial Vehicle Group, Inc.',
#     'primaryExchange': 'NASDAQ',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589809934411,
#     'highSource': 'IEX real time price',
#     'low': None,
#     'lowTime': 1589808601348,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 1.725,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:49:44 AM',
#     'latestUpdate': 1589813384310,
#     'latestVolume': None,
#     'iexRealtimePrice': 1.725,
#     'iexRealtimeSize': 5,
#     'iexLastUpdated': 1589813384310,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 1.55,
#     'previousVolume': 169267,
#     'change': 0.175,
#     'changePercent': 0.1129,
#     'volume': None,
#     'iexMarketPercent': 0.08423294114475936,
#     'iexVolume': 6250,
#     'avgTotalVolume': 332112,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 1.725,
#     'iexCloseTime': 1589813384310,
#     'marketCap': 55158083,
#     'peRatio': 2.72,
#     'week52High': 8.43,
#     'week52Low': 1.24,
#     'ytdChange': -0.6449,
#     'lastTradeTime': 1589813384310,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.16,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'FTK',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'FTK',
#     'companyName': 'Flotek Industries, Inc.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812725078,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589809913791,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 0.8593,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:21:42 AM',
#     'latestUpdate': 1589811702585,
#     'latestVolume': None,
#     'iexRealtimePrice': 0.8593,
#     'iexRealtimeSize': 3800,
#     'iexLastUpdated': 1589811702585,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 0.8162,
#     'previousVolume': 747566,
#     'change': None,
#     'changePercent': None,
#     'volume': None,
#     'iexMarketPercent': 0.01849112426035503,
#     'iexVolume': 4300,
#     'avgTotalVolume': 355056,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 0.8593,
#     'iexCloseTime': 1589811702585,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': None,
#     'week52Low': None,
#     'ytdChange': None,
#     'lastTradeTime': 1589812725047,
#     'isUSMarketOpen': True}},
#   {'consensusEPS': -0.09,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'symbol': 'CBL',
#    'reportDate': '2020-05-18',
#    'currency': 'USD',
#    'quote': {'symbol': 'CBL',
#     'companyName': 'CBL & Associates Properties, Inc.',
#     'primaryExchange': 'New York Stock Exchange',
#     'calculationPrice': 'tops',
#     'open': None,
#     'openTime': None,
#     'openSource': 'official',
#     'close': None,
#     'closeTime': None,
#     'closeSource': 'official',
#     'high': None,
#     'highTime': 1589812765471,
#     'highSource': '15 minute delayed price',
#     'low': None,
#     'lowTime': 1589812152828,
#     'lowSource': '15 minute delayed price',
#     'latestPrice': 0.2196,
#     'latestSource': 'IEX real time price',
#     'latestTime': '10:54:18 AM',
#     'latestUpdate': 1589813658540,
#     'latestVolume': None,
#     'iexRealtimePrice': 0.2196,
#     'iexRealtimeSize': 300,
#     'iexLastUpdated': 1589813658540,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'oddLotDelayedPrice': None,
#     'oddLotDelayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 0.2013,
#     'previousVolume': 7539879,
#     'change': 0.0183,
#     'changePercent': 0.09091,
#     'volume': None,
#     'iexMarketPercent': 0.0084533122002495,
#     'iexVolume': 35819,
#     'avgTotalVolume': 5444355,
#     'iexBidPrice': 0.19,
#     'iexBidSize': 100,
#     'iexAskPrice': 1,
#     'iexAskSize': 200,
#     'iexOpen': None,
#     'iexOpenTime': None,
#     'iexClose': 0.2196,
#     'iexCloseTime': 1589813658540,
#     'marketCap': 47881796,
#     'peRatio': -0.25,
#     'week52High': 1.78,
#     'week52Low': 0.18,
#     'ytdChange': -0.7209899999999999,
#     'lastTradeTime': 1589813658540,
#     'isUSMarketOpen': True}}],
#  'other': []}

# %% [markdown]
# # News

# %%
endpoint = '/stock/TSLA/news'
resp = requests.get(base_url+endpoint, params=params)

# %%
resp.raise_for_status()

# %%
resp.json()
# Out:
# [{'datetime': 1589812753000,
#   'headline': "Why is Elon Musk telling us to 'take the red pill'?",
#   'source': 'The Guardian',
#   'url': 'https://cloud.iexapis.com/v1/news/article/989b5126-544a-42d3-bb8a-6a025821c55f',
#   'summary': 'A cryptic tweet from the Tesla billionaire that referenced the first Matrix movie has garnered approval from Ivanka Trump – but not everyone is happy Coronavirus – latest updates See all our coronavirus coverage Name: The red pill. Age: 21 years. Continue reading…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/989b5126-544a-42d3-bb8a-6a025821c55f',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589812209000,
#   'headline': 'Coronavirus: Apple, Tesla shares surge on positive COVID-19 vaccine report',
#   'source': 'East Bay Times',
#   'url': 'https://cloud.iexapis.com/v1/news/article/b42f8c45-04e1-4ad4-bc3b-a3fd5de6559b',
#   'summary': 'Bay Area business bellwethers such as Apple, Tesla and HP saw their share prices climb Monday as an upbeat report about an early stage coronavirus vaccine trial spurred big gains across Wall Street…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/b42f8c45-04e1-4ad4-bc3b-a3fd5de6559b',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589811151000,
#   'headline': "SpaceX subsidies denied by CA officials over Elon Musk's future Tesla plans",
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/f9aad139-ceb7-401e-8d45-830ca2879d08',
#   'summary': 'SpaceX was recently denied a $655,500 subsidy for job and training funds by a California State panel on Friday. The panel recognized CEO Elon Musk’s recent threats to move Tesla’s company headquarters from California to a new state after Alameda County officials blocked the electric carmaker’s attempt to reopen production lines at its Bay Area …',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/f9aad139-ceb7-401e-8d45-830ca2879d08',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589808129000,
#   'headline': "Greenlight Capital's Q1 13F: David Einhorn Buys Tesla Puts",
#   'source': 'Market Realist',
#   'url': 'https://cloud.iexapis.com/v1/news/article/cf6dd4ea-d86a-490d-b277-d1259e338d99',
#   'summary': 'Greenlight Capital is having a dismal run. The fund lost value in April even though US stock markets had their best month since 1987.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/cf6dd4ea-d86a-490d-b277-d1259e338d99',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589804684000,
#   'headline': 'Las baterías de litio-ferrofosfato llegarán también a los Tesla fabricados en Europa y EE.UU.',
#   'source': 'Publico',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a358fc5f-f2bc-4603-ae29-df66c7ecec61',
#   'summary': 'Las nuevas baterías de litio-ferrofosfato de CATL prometen mayor vida útil y un precio notablemente menor gracias a la eliminación del cobalto. Los Tesla Model 3 fabricados en China empezarán a montarlas este mismo año, pero también llegarán a…',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a358fc5f-f2bc-4603-ae29-df66c7ecec61',
#   'lang': 'es',
#   'hasPaywall': False},
#  {'datetime': 1589803966000,
#   'headline': "Tesla battery partnership becomes Panasonic's silver lining amid painful operating profit drop",
#   'source': 'Teslarati',
#   'url': 'https://cloud.iexapis.com/v1/news/article/ebd531a9-66d3-4d5f-b20e-7e7b408225de',
#   'summary': 'The coronavirus pandemic has not been kind to multiple companies across the globe, and Panasonic has been one of its victims. The Japanese consumer electronics giant is no stranger to the effects of the virus, with the company posting a 29% drop in its annual operating profit. Yet despite these results, one aspect of Panasonic’s …',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/ebd531a9-66d3-4d5f-b20e-7e7b408225de',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589794422000,
#   'headline': 'Xiaomi tiene las cámaras que necesitas para que tu coche se parezca a un Tesla',
#   'source': 'Cinco Dias El Pais',
#   'url': 'https://cloud.iexapis.com/v1/news/article/67cc944a-974a-413a-8140-4479406531ff',
#   'summary': 'Controla todo lo que haces mientras circulas… o no.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/67cc944a-974a-413a-8140-4479406531ff',
#   'lang': 'es',
#   'hasPaywall': False},
#  {'datetime': 1589794200000,
#   'headline': 'Tesla’s Production Restart Could Ease Path to Inclusion in S&P 500 Index',
#   'source': 'The Wall Street Journal',
#   'url': 'https://cloud.iexapis.com/v1/news/article/15e0d5e6-526f-4a2e-bba9-3fec488edd4c',
#   'summary': 'A surprise second-quarter profit could qualify Elon Musk’s car company for its addition to a key investor benchmark.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/15e0d5e6-526f-4a2e-bba9-3fec488edd4c',
#   'lang': 'en',
#   'hasPaywall': True},
#  {'datetime': 1589790600000,
#   'headline': 'Why Intel is betting its chips on microprocessor mastermind Jim Keller',
#   'source': 'Fortune',
#   'url': 'https://cloud.iexapis.com/v1/news/article/a928c8c4-ae01-468d-9f4c-7bfd932c1201',
#   'summary': 'The groundbreaking designer has worked wonders at Apple, Tesla, and AMD. Can he help Intel regain its swagger?',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/a928c8c4-ae01-468d-9f4c-7bfd932c1201',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1589790523000,
#   'headline': 'TSLA Stock Up 1% in Pre-market, Tesla Got Approval to Reopen Fremont Factory',
#   'source': 'Coinspeaker',
#   'url': 'https://cloud.iexapis.com/v1/news/article/055f5aed-3674-4664-982d-f123f1eb3d8a',
#   'summary': 'The latest approval from Fremont health officials means Tesla could soon resume its production now. TSLA stock is up in the pre-market.',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/055f5aed-3674-4664-982d-f123f1eb3d8a',
#   'lang': 'en',
#   'hasPaywall': False}]

# %% [markdown]
# # Investor Exchange Data

# %%
payload = params.copy()
payload['symbols'] = 'TSLA, NFLX'
resp = requests.get(base_url+'/tops/last', params=payload)

# %%
resp.raise_for_status()

# %%
resp.json()
# Out:
# [{'symbol': 'TSLA', 'price': 820.99, 'size': 73, 'time': 1589813405908},
#  {'symbol': 'NFLX', 'price': 451.74, 'size': 50, 'time': 1589813667981}]
